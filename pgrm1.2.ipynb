# %% [markdown]
# <a href="https://colab.research.google.com/github/bumble919/data-science/blob/main/pgrm2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

add_result = np.add(a, b)
print("Addition:", add_result)

sub_result = np.subtract(a, b)
print("Subtraction:", sub_result)

mul_result = np.multiply(a, b)
print("Multiplication:", mul_result)

div_result = np.divide(a, b)
print("Division:", div_result)
# Out:
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Multiplication: [ 4 10 18]
# Division: [0.25 0.4  0.5 ]
